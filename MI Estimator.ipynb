# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MI.csv', sep =';', header=0, index_col=0)

# %%
df.head()
# Out:
#                    PM2.5    PM10     SO2     NO2      O3     CO  Amb Wspeed  \
# Date
# 01:00 01/01/2009   9.380  13.065   5.317   3.160  38.085  0.047        4.70
# 02:00 01/01/2009  12.922  13.360  20.670  12.042  33.463  0.040        4.39
# 03:00 01/01/2009  18.903  19.393  31.210  16.608  22.502  0.243        3.60
# 04:00 01/01/2009   7.577   7.698  10.465   1.843  43.183  0.222        4.87
# 05:00 01/01/2009   5.023   5.407   6.683   3.657  40.870  0.063        2.70
#
#                   Amb WDirection  Temperature  Amb RelHum  ...      SO3   SCO  \
# Date                                                       ...
# 01:00 01/01/2009          177.66        17.15       84.13  ...  18.9172  0.04
# 02:00 01/01/2009          194.34        15.47       94.83  ...  22.9628  0.03
# 03:00 01/01/2009          145.36        15.15       92.28  ...  30.2664  0.04
# 04:00 01/01/2009          112.73        15.05       86.45  ...  20.6410  0.03
# 05:00 01/01/2009           99.15        15.87       79.83  ...  26.0920  0.02
#
#                   SAmb Wspeed  SAmb WDirection  STemperature  SAmb RelHum  \
# Date
# 01:00 01/01/2009         1.09           212.50         14.78       100.00
# 02:00 01/01/2009         1.59           127.76         14.15       100.00
# 03:00 01/01/2009         3.01            69.95         14.03        94.95
# 04:00 01/01/2009         3.16            59.17         14.33        88.58
# 05:00 01/01/2009         2.25            74.02         15.02        81.53
#
#                   SAmb Pressure  SRain  SPM2.5  SPM10
# Date
# 01:00 01/01/2009         847.70    0.0    9.57  12.02
# 02:00 01/01/2009         847.47    0.0    4.89   5.65
# 03:00 01/01/2009         845.63    0.0   11.13  12.07
# 04:00 01/01/2009         844.33    0.0    9.18   9.86
# 05:00 01/01/2009         843.33    0.0    6.78   7.82
#
# [5 rows x 60 columns]

# %%
#df2=df.dropna()

# %%
X = df.copy()
y = X.pop("PM2.5")
discrete_features = X.dtypes == int

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores  # show a few features with their MI scores
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6588/3171622031.py in <module>
#       7     return mi_scores
#       8
# ----> 9 mi_scores = make_mi_scores(X, y, discrete_features)
#      10 mi_scores  # show a few features with their MI scores
#
# ~\AppData\Local\Temp/ipykernel_6588/3171622031.py in make_mi_scores(X, y, discrete_features)
#       2
#       3 def make_mi_scores(X, y, discrete_features):
# ----> 4     mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
#       5     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#       6     mi_scores = mi_scores.sort_values(ascending=False)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state)
#     386            of a Random Vector", Probl. Peredachi Inf., 23:2 (1987), 9-16
#     387     """
# --> 388     return _estimate_mi(X, y, discrete_features, False, n_neighbors, copy, random_state)
#     389
#     390
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_mutual_info.py in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state)
#     268         if discrete_features.dtype != "bool":
#     269             discrete_mask = np.zeros(n_features, dtype=bool)
# --> 270             discrete_mask[discrete_features] = True
#     271         else:
#     272             discrete_mask = discrete_features
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Middelburg Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6588/736646158.py in <module>
#       9
#      10 plt.figure(dpi=100, figsize=(8, 5))
# ---> 11 plot_mi_scores(mi_scores)
#
# NameError: name 'mi_scores' is not defined

# %%
sns.lmplot(x = "PM10", y = "PM2.5", hue = "CO", data = df);

# %%
code credit: https://www.kaggle.com/code/ryanholbrook/mutual-information/tutorial
